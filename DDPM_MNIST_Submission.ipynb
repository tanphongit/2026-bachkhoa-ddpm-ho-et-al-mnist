# %%
# %cd /content

# !rm -rf 2026-bachkhoa-ddpm-ho-et-al-mnist

# !git clone https://github.com/tanphongit/2026-bachkhoa-ddpm-ho-et-al-mnist.git

# %cd 2026-bachkhoa-ddpm-ho-et-al-mnist
# Out:
# [Errno 2] No such file or directory: '/content'
# /Users/roykot/BachKhoa/2026-bachkhoa-ddpm-ho-et-al-mnist/2026-bachkhoa-ddpm-ho-et-al-mnist/2026-bachkhoa-ddpm-ho-et-al-mnist/2026-bachkhoa-ddpm-ho-et-al-mnist
# Cloning into '2026-bachkhoa-ddpm-ho-et-al-mnist'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 43 (delta 14), reused 37 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 243.81 KiB | 2.41 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /Users/roykot/BachKhoa/2026-bachkhoa-ddpm-ho-et-al-mnist/2026-bachkhoa-ddpm-ho-et-al-mnist/2026-bachkhoa-ddpm-ho-et-al-mnist/2026-bachkhoa-ddpm-ho-et-al-mnist/2026-bachkhoa-ddpm-ho-et-al-mnist

# %%
# !pip install -r requirements.txt

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("Device:", "cuda" if torch.cuda.is_available() else "cpu")
# Out:
# CUDA available: False
# Device: cpu

# %%
# File chạy train nhanh để demo nghiên cứu của bài báo
# Thầy có thể thay bằng train.py or train_loop2.py để có những phiên bản tốt hơn trong từng vòng lập
# !python train_loop2.py
# !python train.py
# !python train_fast.py
# Out:
# Device: cpu
# 100%|██████████████████████████████████████| 9.91M/9.91M [00:04<00:00, 1.99MB/s]
# 100%|██████████████████████████████████████| 28.9k/28.9k [00:00<00:00, 88.4kB/s]
# 100%|██████████████████████████████████████| 1.65M/1.65M [00:01<00:00, 1.09MB/s]
# 100%|██████████████████████████████████████| 4.54k/4.54k [00:00<00:00, 8.82MB/s]
# Epoch 1/1: 100%|█████████████████| 156/156 [00:40<00:00,  3.81it/s, loss=0.1156]
# Training complete.
# Checkpoint: checkpoints/diffusion/ddpm_mnist_ep1.pt
# Sample: outputs/diffusion/samples/sample_final.png

# %%
from IPython.display import Image
Image("outputs/diffusion/samples/sample_final.png")

# Các lệnh sau nếu chạy train_loop2.py 
# !python sample.py --ckpt checkpoints/diffusion/ddpm_mnist_ep2.pt --n 16
# from IPython.display import Image
# Image("outputs/diffusion/samples/sample_ep2.png")

# Các lệnh sau nếu chạy train.py
# python sample.py --ckpt checkpoints/ddpm_mnist_ep10.pt
